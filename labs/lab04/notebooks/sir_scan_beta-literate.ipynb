# %% [markdown]
# # Сканирование коэффициента заразности β
#
# **Цель:** Исследовать влияние β на пик эпидемии, конечную долю инфицированных и смертность.
#
# ## Результат
# ![](../plots/beta_scan.png)
