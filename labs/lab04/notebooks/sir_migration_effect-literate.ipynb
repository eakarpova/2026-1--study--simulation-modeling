# %% [markdown]
# # Влияние миграции на эпидемию
#
# **Цель:** Изучить, как интенсивность перемещения людей между городами влияет на время и высоту пика.
#
# ## Результат
# ![](../plots/migration_effect.png)
